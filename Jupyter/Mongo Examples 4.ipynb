// %% [markdown]
// # Mongo Example Part 4
//
// ### Indexing

// %%
use flights;
// Out:
// switched to db flights

// %% [markdown]
// ** Start with one of our queries **

// %%
db.flightstats.find(
    { 
        $and: [
            {"DEST_STATE_ABR": {$eq: "OH"}},
            {"MONTH": {$eq: 6}}, 
            {"DAY_OF_MONTH": {$eq: 15}},
            {"ARR_DELAY": {$lt: 0}}
        ]}
    ).explain();
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="a17aa138-bc92-4fa6-b29d-065df93a0ba6"></div>
// {
// 	"queryPlanner" : {
// 		"plannerVersion" : 1,
// 		"namespace" : "flights.flightstats",
// 		"indexFilterSet" : false,
// 		"parsedQuery" : {
// 			"$and" : [
// 				{
// 					"DAY_OF_MONTH" : {
// 						"$eq" : 15
// 					}
// 				},
// 				{
// 					"DEST_STATE_ABR" : {
// 						"$eq" : "OH"
// 					}
// 				},
// 				{
// 					"MONTH" : {
// 						"$eq" : 6
// 					}
// 				},
// 				{
// 					"ARR_DELAY" : {
// 						"$lt" : 0
// 					}
// 				}
// 			]
// 		},
// 		"winningPlan" : {
// 			"stage" : "FETCH",
// 			"filter" : {
// 				"$and" : [
// 					{
// 						"DAY_OF_MONTH" : {
// 							"$eq" : 15
// 						}
// 					},
// 					{
// 						"MONTH" : {
// 							"$eq" : 6
// 						}
// 					},
// 					{
// 						"ARR_DELAY" : {
// 							"$lt" : 0
// 						}
// 					}
// 				]
// 			},
// 			"inputStage" : {
// 				"stage" : "IXSCAN",
// 				"keyPattern" : {
// 					"DEST_STATE_ABR" : 1
// 				},
// 				"indexName" : "DEST_STATE_ABR_1",
// 				"isMultiKey" : false,
// 				"multiKeyPaths" : {
// 					"DEST_STATE_ABR" : [ ]
// 				},
// 				"isUnique" : false,
// 				"isSparse" : false,
// 				"isPartial" : false,
// 				"indexVersion" : 2,
// 				"direction" : "forward",
// 				"indexBounds" : {
// 					"DEST_STATE_ABR" : [
// 						"[\"OH\", \"OH\"]"
// 					]
// 				}
// 			}
// 		},
// 		"rejectedPlans" : [
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DAY_OF_MONTH" : {
// 								"$eq" : 15
// 							}
// 						},
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"MONTH" : {
// 								"$eq" : 6
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "IXSCAN",
// 					"keyPattern" : {
// 						"ARR_DELAY" : 1
// 					},
// 					"indexName" : "ARR_DELAY_1",
// 					"isMultiKey" : false,
// 					"multiKeyPaths" : {
// 						"ARR_DELAY" : [ ]
// 					},
// 					"isUnique" : false,
// 					"isSparse" : false,
// 					"isPartial" : false,
// 					"indexVersion" : 2,
// 					"direction" : "forward",
// 					"indexBounds" : {
// 						"ARR_DELAY" : [
// 							"[-inf.0, 0.0)"
// 						]
// 					}
// 				}
// 			},
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"ARR_DELAY" : {
// 								"$lt" : 0
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "IXSCAN",
// 					"keyPattern" : {
// 						"MONTH" : 1,
// 						"DAY_OF_MONTH" : 1
// 					},
// 					"indexName" : "MONTH_1_DAY_OF_MONTH_1",
// 					"isMultiKey" : false,
// 					"multiKeyPaths" : {
// 						"MONTH" : [ ],
// 						"DAY_OF_MONTH" : [ ]
// 					},
// 					"isUnique" : false,
// 					"isSparse" : false,
// 					"isPartial" : false,
// 					"indexVersion" : 2,
// 					"direction" : "forward",
// 					"indexBounds" : {
// 						"MONTH" : [
// 							"[6.0, 6.0]"
// 						],
// 						"DAY_OF_MONTH" : [
// 							"[15.0, 15.0]"
// 						]
// 					}
// 				}
// 			},
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"MONTH" : {
// 								"$eq" : 6
// 							}
// 						},
// 						{
// 							"DAY_OF_MONTH" : {
// 								"$eq" : 15
// 							}
// 						},
// 						{
// 							"ARR_DELAY" : {
// 								"$lt" : 0
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "AND_SORTED",
// 					"inputStages" : [
// 						{
// 							"stage" : "IXSCAN",
// 							"keyPattern" : {
// 								"DEST_STATE_ABR" : 1
// 							},
// 							"indexName" : "DEST_STATE_ABR_1",
// 							"isMultiKey" : false,
// 							"multiKeyPaths" : {
// 								"DEST_STATE_ABR" : [ ]
// 							},
// 							"isUnique" : false,
// 							"isSparse" : false,
// 							"isPartial" : false,
// 							"indexVersion" : 2,
// 							"direction" : "forward",
// 							"indexBounds" : {
// 								"DEST_STATE_ABR" : [
// 									"[\"OH\", \"OH\"]"
// 								]
// 							}
// 						},
// 						{
// 							"stage" : "IXSCAN",
// 							"keyPattern" : {
// 								"MONTH" : 1,
// 								"DAY_OF_MONTH" : 1
// 							},
// 							"indexName" : "MONTH_1_DAY_OF_MONTH_1",
// 							"isMultiKey" : false,
// 							"multiKeyPaths" : {
// 								"MONTH" : [ ],
// 								"DAY_OF_MONTH" : [ ]
// 							},
// 							"isUnique" : false,
// 							"isSparse" : false,
// 							"isPartial" : false,
// 							"indexVersion" : 2,
// 							"direction" : "forward",
// 							"indexBounds" : {
// 								"MONTH" : [
// 									"[6.0, 6.0]"
// 								],
// 								"DAY_OF_MONTH" : [
// 									"[15.0, 15.0]"
// 								]
// 							}
// 						}
// 					]
// 				}
// 			}
// 		]
// 	},
// 	"serverInfo" : {
// 		"host" : "BillsBonobo",
// 		"port" : 27017,
// 		"version" : "3.4.9",
// 		"gitVersion" : "876ebee8c7dd0e2d992f36a848ff4dc50ee6603e"
// 	},
// 	"ok" : 1
// }

// %%
db.flightstats.find(
    { 
        $and: [
            {"DEST_STATE_ABR": {$eq: "OH"}},
            {"MONTH": {$eq: 6}}, 
            {"DAY_OF_MONTH": {$eq: 15}},
            {"ARR_DELAY": {$lt: 0}}
        ]}
    ).explain("executionStats");
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="514f1f6b-693c-49bd-b032-b8902af352ba"></div>
// {
// 	"queryPlanner" : {
// 		"plannerVersion" : 1,
// 		"namespace" : "flights.flightstats",
// 		"indexFilterSet" : false,
// 		"parsedQuery" : {
// 			"$and" : [
// 				{
// 					"DAY_OF_MONTH" : {
// 						"$eq" : 15
// 					}
// 				},
// 				{
// 					"DEST_STATE_ABR" : {
// 						"$eq" : "OH"
// 					}
// 				},
// 				{
// 					"MONTH" : {
// 						"$eq" : 6
// 					}
// 				},
// 				{
// 					"ARR_DELAY" : {
// 						"$lt" : 0
// 					}
// 				}
// 			]
// 		},
// 		"winningPlan" : {
// 			"stage" : "FETCH",
// 			"filter" : {
// 				"$and" : [
// 					{
// 						"DAY_OF_MONTH" : {
// 							"$eq" : 15
// 						}
// 					},
// 					{
// 						"MONTH" : {
// 							"$eq" : 6
// 						}
// 					},
// 					{
// 						"ARR_DELAY" : {
// 							"$lt" : 0
// 						}
// 					}
// 				]
// 			},
// 			"inputStage" : {
// 				"stage" : "IXSCAN",
// 				"keyPattern" : {
// 					"DEST_STATE_ABR" : 1
// 				},
// 				"indexName" : "DEST_STATE_ABR_1",
// 				"isMultiKey" : false,
// 				"multiKeyPaths" : {
// 					"DEST_STATE_ABR" : [ ]
// 				},
// 				"isUnique" : false,
// 				"isSparse" : false,
// 				"isPartial" : false,
// 				"indexVersion" : 2,
// 				"direction" : "forward",
// 				"indexBounds" : {
// 					"DEST_STATE_ABR" : [
// 						"[\"OH\", \"OH\"]"
// 					]
// 				}
// 			}
// 		},
// 		"rejectedPlans" : [
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DAY_OF_MONTH" : {
// 								"$eq" : 15
// 							}
// 						},
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"MONTH" : {
// 								"$eq" : 6
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "IXSCAN",
// 					"keyPattern" : {
// 						"ARR_DELAY" : 1
// 					},
// 					"indexName" : "ARR_DELAY_1",
// 					"isMultiKey" : false,
// 					"multiKeyPaths" : {
// 						"ARR_DELAY" : [ ]
// 					},
// 					"isUnique" : false,
// 					"isSparse" : false,
// 					"isPartial" : false,
// 					"indexVersion" : 2,
// 					"direction" : "forward",
// 					"indexBounds" : {
// 						"ARR_DELAY" : [
// 							"[-inf.0, 0.0)"
// 						]
// 					}
// 				}
// 			},
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"ARR_DELAY" : {
// 								"$lt" : 0
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "IXSCAN",
// 					"keyPattern" : {
// 						"MONTH" : 1,
// 						"DAY_OF_MONTH" : 1
// 					},
// 					"indexName" : "MONTH_1_DAY_OF_MONTH_1",
// 					"isMultiKey" : false,
// 					"multiKeyPaths" : {
// 						"MONTH" : [ ],
// 						"DAY_OF_MONTH" : [ ]
// 					},
// 					"isUnique" : false,
// 					"isSparse" : false,
// 					"isPartial" : false,
// 					"indexVersion" : 2,
// 					"direction" : "forward",
// 					"indexBounds" : {
// 						"MONTH" : [
// 							"[6.0, 6.0]"
// 						],
// 						"DAY_OF_MONTH" : [
// 							"[15.0, 15.0]"
// 						]
// 					}
// 				}
// 			},
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"MONTH" : {
// 								"$eq" : 6
// 							}
// 						},
// 						{
// 							"DAY_OF_MONTH" : {
// 								"$eq" : 15
// 							}
// 						},
// 						{
// 							"ARR_DELAY" : {
// 								"$lt" : 0
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "AND_SORTED",
// 					"inputStages" : [
// 						{
// 							"stage" : "IXSCAN",
// 							"keyPattern" : {
// 								"DEST_STATE_ABR" : 1
// 							},
// 							"indexName" : "DEST_STATE_ABR_1",
// 							"isMultiKey" : false,
// 							"multiKeyPaths" : {
// 								"DEST_STATE_ABR" : [ ]
// 							},
// 							"isUnique" : false,
// 							"isSparse" : false,
// 							"isPartial" : false,
// 							"indexVersion" : 2,
// 							"direction" : "forward",
// 							"indexBounds" : {
// 								"DEST_STATE_ABR" : [
// 									"[\"OH\", \"OH\"]"
// 								]
// 							}
// 						},
// 						{
// 							"stage" : "IXSCAN",
// 							"keyPattern" : {
// 								"MONTH" : 1,
// 								"DAY_OF_MONTH" : 1
// 							},
// 							"indexName" : "MONTH_1_DAY_OF_MONTH_1",
// 							"isMultiKey" : false,
// 							"multiKeyPaths" : {
// 								"MONTH" : [ ],
// 								"DAY_OF_MONTH" : [ ]
// 							},
// 							"isUnique" : false,
// 							"isSparse" : false,
// 							"isPartial" : false,
// 							"indexVersion" : 2,
// 							"direction" : "forward",
// 							"indexBounds" : {
// 								"MONTH" : [
// 									"[6.0, 6.0]"
// 								],
// 								"DAY_OF_MONTH" : [
// 									"[15.0, 15.0]"
// 								]
// 							}
// 						}
// 					]
// 				}
// 			}
// 		]
// 	},
// 	"executionStats" : {
// 		"executionSuccess" : true,
// 		"nReturned" : 95,
// 		"executionTimeMillis" : 48,
// 		"totalKeysExamined" : 6233,
// 		"totalDocsExamined" : 6233,
// 		"executionStages" : {
// 			"stage" : "FETCH",
// 			"filter" : {
// 				"$and" : [
// 					{
// 						"DAY_OF_MONTH" : {
// 							"$eq" : 15
// 						}
// 					},
// 					{
// 						"MONTH" : {
// 							"$eq" : 6
// 						}
// 					},
// 					{
// 						"ARR_DELAY" : {
// 							"$lt" : 0
// 						}
// 					}
// 				]
// 			},
// 			"nReturned" : 95,
// 			"executionTimeMillisEstimate" : 20,
// 			"works" : 6235,
// 			"advanced" : 95,
// 			"needTime" : 6138,
// 			"needYield" : 0,
// 			"saveState" : 195,
// 			"restoreState" : 195,
// 			"isEOF" : 1,
// 			"invalidates" : 0,
// 			"docsExamined" : 6233,
// 			"alreadyHasObj" : 0,
// 			"inputStage" : {
// 				"stage" : "IXSCAN",
// 				"nReturned" : 6233,
// 				"executionTimeMillisEstimate" : 0,
// 				"works" : 6234,
// 				"advanced" : 6233,
// 				"needTime" : 0,
// 				"needYield" : 0,
// 				"saveState" : 195,
// 				"restoreState" : 195,
// 				"isEOF" : 1,
// 				"invalidates" : 0,
// 				"keyPattern" : {
// 					"DEST_STATE_ABR" : 1
// 				},
// 				"indexName" : "DEST_STATE_ABR_1",
// 				"isMultiKey" : false,
// 				"multiKeyPaths" : {
// 					"DEST_STATE_ABR" : [ ]
// 				},
// 				"isUnique" : false,
// 				"isSparse" : false,
// 				"isPartial" : false,
// 				"indexVersion" : 2,
// 				"direction" : "forward",
// 				"indexBounds" : {
// 					"DEST_STATE_ABR" : [
// 						"[\"OH\", \"OH\"]"
// 					]
// 				},
// 				"keysExamined" : 6233,
// 				"seeks" : 1,
// 				"dupsTested" : 0,
// 				"dupsDropped" : 0,
// 				"seenInvalidated" : 0
// 			}
// 		}
// 	},
// 	"serverInfo" : {
// 		"host" : "BillsBonobo",
// 		"port" : 27017,
// 		"version" : "3.4.9",
// 		"gitVersion" : "876ebee8c7dd0e2d992f36a848ff4dc50ee6603e"
// 	},
// 	"ok" : 1
// }

// %% [markdown]
// ** Create an index that fits our needs **

// %%
db.flightstats.createIndex({"DEST_STATE_ABR": 1, "MONTH": 1, "DAY_OF_MONTH": 1, "ARR_DELAY": 1});
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="fe28aad5-3c4f-44bb-956a-103c07da6259"></div>
// {
// 	"createdCollectionAutomatically" : false,
// 	"numIndexesBefore" : 4,
// 	"numIndexesAfter" : 5,
// 	"ok" : 1
// }

// %%
db.flightstats.getIndexes();
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="23b855f0-c893-4f46-ab3d-baa535948a72"></div>
// [
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"_id" : 1
// 		},
// 		"name" : "_id_",
// 		"ns" : "flights.flightstats"
// 	},
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"DEST_STATE_ABR" : 1
// 		},
// 		"name" : "DEST_STATE_ABR_1",
// 		"ns" : "flights.flightstats"
// 	},
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"MONTH" : 1,
// 			"DAY_OF_MONTH" : 1
// 		},
// 		"name" : "MONTH_1_DAY_OF_MONTH_1",
// 		"ns" : "flights.flightstats"
// 	},
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"ARR_DELAY" : 1
// 		},
// 		"name" : "ARR_DELAY_1",
// 		"ns" : "flights.flightstats"
// 	},
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"DEST_STATE_ABR" : 1,
// 			"MONTH" : 1,
// 			"DAY_OF_MONTH" : 1,
// 			"ARR_DELAY" : 1
// 		},
// 		"name" : "DEST_STATE_ABR_1_MONTH_1_DAY_OF_MONTH_1_ARR_DELAY_1",
// 		"ns" : "flights.flightstats"
// 	}
// ]

// %% [markdown]
// ** See how that impacts our query **

// %%
db.flightstats.find(
    { 
        $and: [
            {"DEST_STATE_ABR": {$eq: "OH"}},
            {"MONTH": {$eq: 6}}, 
            {"DAY_OF_MONTH": {$eq: 15}},
            {"ARR_DELAY": {$lt: 0}}
        ]}
    ).explain("executionStats");

// %%
db.flightstats.dropIndex({"DEST_STATE_ABR": 1, "MONTH": 1, "DAY_OF_MONTH": 1, "ARR_DELAY": 1});
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="4d1abe5e-8b14-4f1d-8001-b6e53baac2ea"></div>
// { "nIndexesWas" : 5, "ok" : 1 }

// %%
db.flightstats.createIndex({"DEST_STATE_ABR": 1})
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="02258eb4-dca5-4bf8-993e-59b27a65c3bb"></div>
// {
// 	"createdCollectionAutomatically" : false,
// 	"numIndexesBefore" : 4,
// 	"numIndexesAfter" : 4,
// 	"note" : "all indexes already exist",
// 	"ok" : 1
// }

// %%
db.flightstats.createIndex({"MONTH": 1, "DAY_OF_MONTH": 1});
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="f5cdc1a1-9d8b-4e97-9a53-3309aff20f57"></div>
// {
// 	"createdCollectionAutomatically" : false,
// 	"numIndexesBefore" : 4,
// 	"numIndexesAfter" : 4,
// 	"note" : "all indexes already exist",
// 	"ok" : 1
// }

// %%
db.flightstats.createIndex({"ARR_DELAY": 1});
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="a403b665-036e-4990-a947-ac6dfe0fde2d"></div>
// {
// 	"createdCollectionAutomatically" : false,
// 	"numIndexesBefore" : 4,
// 	"numIndexesAfter" : 4,
// 	"note" : "all indexes already exist",
// 	"ok" : 1
// }

// %%
db.flightstats.getIndexes();
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="484a2c44-df5a-4387-9c57-ba18357513e8"></div>
// [
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"_id" : 1
// 		},
// 		"name" : "_id_",
// 		"ns" : "flights.flightstats"
// 	},
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"DEST_STATE_ABR" : 1
// 		},
// 		"name" : "DEST_STATE_ABR_1",
// 		"ns" : "flights.flightstats"
// 	},
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"MONTH" : 1,
// 			"DAY_OF_MONTH" : 1
// 		},
// 		"name" : "MONTH_1_DAY_OF_MONTH_1",
// 		"ns" : "flights.flightstats"
// 	},
// 	{
// 		"v" : 2,
// 		"key" : {
// 			"ARR_DELAY" : 1
// 		},
// 		"name" : "ARR_DELAY_1",
// 		"ns" : "flights.flightstats"
// 	}
// ]

// %%
db.flightstats.find(
    { 
        $and: [
            {"DEST_STATE_ABR": {$eq: "OH"}},
            {"MONTH": {$eq: 6}}, 
            {"DAY_OF_MONTH": {$eq: 15}},
            {"ARR_DELAY": {$lt: 0}}
        ]}
    ).explain("executionStats");
// Out:
// <style>a.disclosure:link{text-decoration:none;}a.disclosure:visited{text-decoration:none;}.disclosure{color:#337AB7;font-size:150%;}.syntax{color:grey;}.string{color:#9A334F;}.number{color:#5C9632;}.boolean{color:#AA9739;}.key{color:#403075;}.keyword{color:#AA9739;}.object.syntax{color:#337AB7;}.array.syntax{color:#337AB7;}></style><div id="38f33562-a83a-4ccb-9243-41fee6d1e545"></div>
// {
// 	"queryPlanner" : {
// 		"plannerVersion" : 1,
// 		"namespace" : "flights.flightstats",
// 		"indexFilterSet" : false,
// 		"parsedQuery" : {
// 			"$and" : [
// 				{
// 					"DAY_OF_MONTH" : {
// 						"$eq" : 15
// 					}
// 				},
// 				{
// 					"DEST_STATE_ABR" : {
// 						"$eq" : "OH"
// 					}
// 				},
// 				{
// 					"MONTH" : {
// 						"$eq" : 6
// 					}
// 				},
// 				{
// 					"ARR_DELAY" : {
// 						"$lt" : 0
// 					}
// 				}
// 			]
// 		},
// 		"winningPlan" : {
// 			"stage" : "FETCH",
// 			"filter" : {
// 				"$and" : [
// 					{
// 						"DAY_OF_MONTH" : {
// 							"$eq" : 15
// 						}
// 					},
// 					{
// 						"MONTH" : {
// 							"$eq" : 6
// 						}
// 					},
// 					{
// 						"ARR_DELAY" : {
// 							"$lt" : 0
// 						}
// 					}
// 				]
// 			},
// 			"inputStage" : {
// 				"stage" : "IXSCAN",
// 				"keyPattern" : {
// 					"DEST_STATE_ABR" : 1
// 				},
// 				"indexName" : "DEST_STATE_ABR_1",
// 				"isMultiKey" : false,
// 				"multiKeyPaths" : {
// 					"DEST_STATE_ABR" : [ ]
// 				},
// 				"isUnique" : false,
// 				"isSparse" : false,
// 				"isPartial" : false,
// 				"indexVersion" : 2,
// 				"direction" : "forward",
// 				"indexBounds" : {
// 					"DEST_STATE_ABR" : [
// 						"[\"OH\", \"OH\"]"
// 					]
// 				}
// 			}
// 		},
// 		"rejectedPlans" : [
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DAY_OF_MONTH" : {
// 								"$eq" : 15
// 							}
// 						},
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"MONTH" : {
// 								"$eq" : 6
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "IXSCAN",
// 					"keyPattern" : {
// 						"ARR_DELAY" : 1
// 					},
// 					"indexName" : "ARR_DELAY_1",
// 					"isMultiKey" : false,
// 					"multiKeyPaths" : {
// 						"ARR_DELAY" : [ ]
// 					},
// 					"isUnique" : false,
// 					"isSparse" : false,
// 					"isPartial" : false,
// 					"indexVersion" : 2,
// 					"direction" : "forward",
// 					"indexBounds" : {
// 						"ARR_DELAY" : [
// 							"[-inf.0, 0.0)"
// 						]
// 					}
// 				}
// 			},
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"ARR_DELAY" : {
// 								"$lt" : 0
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "IXSCAN",
// 					"keyPattern" : {
// 						"MONTH" : 1,
// 						"DAY_OF_MONTH" : 1
// 					},
// 					"indexName" : "MONTH_1_DAY_OF_MONTH_1",
// 					"isMultiKey" : false,
// 					"multiKeyPaths" : {
// 						"MONTH" : [ ],
// 						"DAY_OF_MONTH" : [ ]
// 					},
// 					"isUnique" : false,
// 					"isSparse" : false,
// 					"isPartial" : false,
// 					"indexVersion" : 2,
// 					"direction" : "forward",
// 					"indexBounds" : {
// 						"MONTH" : [
// 							"[6.0, 6.0]"
// 						],
// 						"DAY_OF_MONTH" : [
// 							"[15.0, 15.0]"
// 						]
// 					}
// 				}
// 			},
// 			{
// 				"stage" : "FETCH",
// 				"filter" : {
// 					"$and" : [
// 						{
// 							"DEST_STATE_ABR" : {
// 								"$eq" : "OH"
// 							}
// 						},
// 						{
// 							"MONTH" : {
// 								"$eq" : 6
// 							}
// 						},
// 						{
// 							"DAY_OF_MONTH" : {
// 								"$eq" : 15
// 							}
// 						},
// 						{
// 							"ARR_DELAY" : {
// 								"$lt" : 0
// 							}
// 						}
// 					]
// 				},
// 				"inputStage" : {
// 					"stage" : "AND_SORTED",
// 					"inputStages" : [
// 						{
// 							"stage" : "IXSCAN",
// 							"keyPattern" : {
// 								"DEST_STATE_ABR" : 1
// 							},
// 							"indexName" : "DEST_STATE_ABR_1",
// 							"isMultiKey" : false,
// 							"multiKeyPaths" : {
// 								"DEST_STATE_ABR" : [ ]
// 							},
// 							"isUnique" : false,
// 							"isSparse" : false,
// 							"isPartial" : false,
// 							"indexVersion" : 2,
// 							"direction" : "forward",
// 							"indexBounds" : {
// 								"DEST_STATE_ABR" : [
// 									"[\"OH\", \"OH\"]"
// 								]
// 							}
// 						},
// 						{
// 							"stage" : "IXSCAN",
// 							"keyPattern" : {
// 								"MONTH" : 1,
// 								"DAY_OF_MONTH" : 1
// 							},
// 							"indexName" : "MONTH_1_DAY_OF_MONTH_1",
// 							"isMultiKey" : false,
// 							"multiKeyPaths" : {
// 								"MONTH" : [ ],
// 								"DAY_OF_MONTH" : [ ]
// 							},
// 							"isUnique" : false,
// 							"isSparse" : false,
// 							"isPartial" : false,
// 							"indexVersion" : 2,
// 							"direction" : "forward",
// 							"indexBounds" : {
// 								"MONTH" : [
// 									"[6.0, 6.0]"
// 								],
// 								"DAY_OF_MONTH" : [
// 									"[15.0, 15.0]"
// 								]
// 							}
// 						}
// 					]
// 				}
// 			}
// 		]
// 	},
// 	"executionStats" : {
// 		"executionSuccess" : true,
// 		"nReturned" : 95,
// 		"executionTimeMillis" : 51,
// 		"totalKeysExamined" : 6233,
// 		"totalDocsExamined" : 6233,
// 		"executionStages" : {
// 			"stage" : "FETCH",
// 			"filter" : {
// 				"$and" : [
// 					{
// 						"DAY_OF_MONTH" : {
// 							"$eq" : 15
// 						}
// 					},
// 					{
// 						"MONTH" : {
// 							"$eq" : 6
// 						}
// 					},
// 					{
// 						"ARR_DELAY" : {
// 							"$lt" : 0
// 						}
// 					}
// 				]
// 			},
// 			"nReturned" : 95,
// 			"executionTimeMillisEstimate" : 10,
// 			"works" : 6235,
// 			"advanced" : 95,
// 			"needTime" : 6138,
// 			"needYield" : 0,
// 			"saveState" : 195,
// 			"restoreState" : 195,
// 			"isEOF" : 1,
// 			"invalidates" : 0,
// 			"docsExamined" : 6233,
// 			"alreadyHasObj" : 0,
// 			"inputStage" : {
// 				"stage" : "IXSCAN",
// 				"nReturned" : 6233,
// 				"executionTimeMillisEstimate" : 10,
// 				"works" : 6234,
// 				"advanced" : 6233,
// 				"needTime" : 0,
// 				"needYield" : 0,
// 				"saveState" : 195,
// 				"restoreState" : 195,
// 				"isEOF" : 1,
// 				"invalidates" : 0,
// 				"keyPattern" : {
// 					"DEST_STATE_ABR" : 1
// 				},
// 				"indexName" : "DEST_STATE_ABR_1",
// 				"isMultiKey" : false,
// 				"multiKeyPaths" : {
// 					"DEST_STATE_ABR" : [ ]
// 				},
// 				"isUnique" : false,
// 				"isSparse" : false,
// 				"isPartial" : false,
// 				"indexVersion" : 2,
// 				"direction" : "forward",
// 				"indexBounds" : {
// 					"DEST_STATE_ABR" : [
// 						"[\"OH\", \"OH\"]"
// 					]
// 				},
// 				"keysExamined" : 6233,
// 				"seeks" : 1,
// 				"dupsTested" : 0,
// 				"dupsDropped" : 0,
// 				"seenInvalidated" : 0
// 			}
// 		}
// 	},
// 	"serverInfo" : {
// 		"host" : "BillsBonobo",
// 		"port" : 27017,
// 		"version" : "3.4.9",
// 		"gitVersion" : "876ebee8c7dd0e2d992f36a848ff4dc50ee6603e"
// 	},
// 	"ok" : 1
// }
